# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
n=pd.read_csv('netflix.csv')
n
#display origin country(united states) of series/movies:
#indicates the type of content
#how many movie/series relese after 2018
#Total movie relesed
#Total TV SHOW relesed
#content relesed in united states only
#list the tv show releses in united states
#show all the content which relesed after 2015
#show the content which relsed after 2015 and before 2020
#show the tv show which has 3 season 
#show the most num of TV_MA rating content
#show the comedy genre tv show or movies
#show the content which lenght r greater than 90 min and more than 1 season
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
n.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#display origin country(united states) of series/movies:
n['title'].loc[n['country']=='United States'].value_counts()
# Out:
# Dick Johnson Is Dead             1
# Grease                           1
# Badland                          1
# Balto                            1
# Balto 2: Wolf Quest              1
#                                 ..
# The Knight Before Christmas      1
# Bikram: Yogi, Guru, Predator     1
# Iliza Shlesinger: Unveiled       1
# Jeff Dunham: All Over the Map    1
# Zoom                             1
# Name: title, Length: 2818, dtype: int64

# %%
#indicates the type of content
n['type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
n.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
#how many movie/series relese after 2018
n['release_year'].loc[n['release_year']>2018].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Total movie relesed
n['type'].loc[n['type']=='Movie'].value_counts()
# Out:
# Movie    6131
# Name: type, dtype: int64

# %%
#Total tv show relesed
n['type'].loc[n['type']=='TV Show'].value_counts()
# Out:
# TV Show    2676
# Name: type, dtype: int64

# %%
#content relesed i united states only
n['country'].loc[n['country']=='United States'].value_counts()
# Out:
# United States    2818
# Name: country, dtype: int64

# %%
#list the tv show releses in united states
n.loc[(n['country']=='United States') & (n['type']=='TV Show')]
# Out:
#      show_id     type                                   title director  \
# 15       s16  TV Show                       Dear White People      NaN
# 40       s41  TV Show  He-Man and the Masters of the Universe      NaN
# 55       s56  TV Show                               Nailed It      NaN
# 67       s68  TV Show                       Saved by the Bell      NaN
# 82       s83  TV Show                                 Lucifer      NaN
# ...      ...      ...                                     ...      ...
# 8710   s8711  TV Show                                   Weeds      NaN
# 8726   s8727  TV Show                    When Calls the Heart      NaN
# 8747   s8748  TV Show                               Winsanity      NaN
# 8755   s8756  TV Show                       Women Behind Bars      NaN
# 8780   s8781  TV Show                            Yo-Kai Watch      NaN
#
#                                                    cast        country  \
# ...

# %%
n.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description
# 0  As her father nears the end of his life, filmm...

# %%
n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
n.loc[(n['date_added']=='September 22, 2021') & (n['type']=='TV Show')]
# Out:
#    show_id     type                                            title  \
# 14     s15  TV Show                  Crime Stories: India Detectives
# 15     s16  TV Show                                Dear White People
# 17     s18  TV Show                                  Falsa identidad
# 19     s20  TV Show                                           Jaguar
# 20     s21  TV Show  Monsters Inside: The 24 Faces of Billy Milligan
# 21     s22  TV Show                           Resurrection: Ertugrul
#
#            director                                               cast  \
# 14              NaN                                                NaN
# 15              NaN  Logan Browning, Brandon P. Bell, DeRon Horton,...
# 17              NaN  Luis Ernesto Franco, Camila Sodi, Sergio Goyri...
# 19              NaN  Blanca Suárez, Iván Marcos, Óscar Casas, Adriá...
# 20  Olivier Megaton                                                NaN
# ...

# %%
n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
n
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
n.loc[n['release_year']>2015]
#show all the content which relesed after 2015
# Out:
#      show_id     type                      title         director  \
# 0         s1    Movie       Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# ...      ...      ...                        ...              ...
# 8787   s8788    Movie  You Can’t Fight Christmas      Kenny Young
# 8794   s8795    Movie                     اشتباك     Mohamed Diab
# 8796   s8797  TV Show                 Yunus Emre              NaN
# 8797   s8798  TV Show                  Zak Storm              NaN
# 8803   s8804  TV Show                Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
n.loc[ (n['release_year'] > 2015) &( n['release_year'] < 2020)]
#show the content which relsed after 2015 and before 2020
# Out:
#      show_id     type                      title      director  \
# 21       s22  TV Show     Resurrection: Ertugrul           NaN
# 37       s38  TV Show                Angry Birds           NaN
# 38       s39    Movie        Birth of the Dragon  George Nolfi
# 73       s74    Movie               King of Boys  Kemi Adetiba
# 87       s88  TV Show              Titipo Titipo           NaN
# ...      ...      ...                        ...           ...
# 8787   s8788    Movie  You Can’t Fight Christmas   Kenny Young
# 8794   s8795    Movie                     اشتباك  Mohamed Diab
# 8796   s8797  TV Show                 Yunus Emre           NaN
# 8797   s8798  TV Show                  Zak Storm           NaN
# 8803   s8804  TV Show                Zombie Dumb           NaN
#
#                                                    cast  \
# 21    Engin Altan Düzyatan, Serdar Gökhan, Hülya Dar...
# 37    Antti Pääkkönen, Heljä Heikkinen, Lynne Guagli...
# ...

# %%
#show the tv show which has 3 season 
n.loc[(n['type']=='TV Show') & (n['duration']== '3 Seasons')]
# Out:
#      show_id     type                        title         director  \
# 32       s33  TV Show                Sex Education              NaN
# 39       s40  TV Show                 Chhota Bheem              NaN
# 95       s96  TV Show                   The Circle              NaN
# 124     s125  TV Show  Pororo - The Little Penguin              NaN
# 154     s155  TV Show          Kuroko's Basketball              NaN
# ...      ...      ...                          ...              ...
# 8599   s8600  TV Show              Toast of London  Michael Cumming
# 8605   s8606  TV Show                    Top Grier              NaN
# 8684   s8685  TV Show                      Vroomiz              NaN
# 8755   s8756  TV Show            Women Behind Bars              NaN
# 8797   s8798  TV Show                    Zak Storm              NaN
#
#                                                    cast  \
# 32    Asa Butterfield, Gillian Anderson, Ncuti Gatwa...
# ...

# %%
plt.figure(figsize=(10,10))
n['rating'].value_counts().plot(kind='pie',autopct='%1.1f%%')
#show the most num of TV_MA rating content
# Out:
# <AxesSubplot:ylabel='rating'>

# %%
n.loc[n['listed_in']=='Comedies']
#show the comedy genre tv show or movies
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %%
n.loc[(n['duration']>'90 min') & (n['duration']> '1 Seasons')]
#show the content which lenght r greater than 90 min and more than 1 season
# Out:
#      show_id   type                             title  \
# 6         s7  Movie  My Little Pony: A New Generation
# 13       s14  Movie  Confessions of an Invisible Girl
# 18       s19  Movie                         Intrusion
# 28       s29  Movie                        Dark Skies
# 38       s39  Movie               Birth of the Dragon
# ...      ...    ...                               ...
# 8774   s8775  Movie                         يوم الدين
# 8781   s8782  Movie           Yo-Kai Watch: The Movie
# 8791   s8792  Movie                       Young Adult
# 8794   s8795  Movie                            اشتباك
# 8801   s8802  Movie                           Zinzana
#
#                            director  \
# 6     Robert Cullen, José Luis Ucha
# 13                    Bruno Garotti
# 18                       Adam Salky
# 28                    Scott Stewart
# 38                     George Nolfi
# ...                             ...
# 8774                Abu Bakr Shawky
# ...
